# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\amitk\onedrive\desktop\complete data analyst bootcamp\venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\amitk\onedrive\desktop\complete data analyst bootcamp\venv\lib\site-packages (from seaborn) (2.4.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\amitk\onedrive\desktop\complete data analyst bootcamp\venv\lib\site-packages (from seaborn) (3.0.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\amitk\onedrive\desktop\complete data analyst bootcamp\venv\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\amitk\onedrive\desktop\complete data analyst bootcamp\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\amitk\onedrive\desktop\complete data analyst bootcamp\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\amitk\onedrive\desktop\complete data analyst bootcamp\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\amitk\onedrive\desktop\complete data analyst bootcamp\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\amitk\onedrive\desktop\complete data analyst bootcamp\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\amitk\onedrive\desktop\complete data analyst bootcamp\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\amitk\onedrive\desktop\complete data analyst bootcamp\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\amitk\onedrive\desktop\complete data analyst bootcamp\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\amitk\onedrive\desktop\complete data analyst bootcamp\venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\amitk\onedrive\desktop\complete data analyst bootcamp\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import seaborn as sns

# %%
## Basic Plotting with seaborn
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
## Creating scattering plot
import matplotlib.pyplot as plt
sns.scatterplot(x='total_bill',y='tip',data=tips)
plt.title("Scatter plot of total_bill vs tip")
plt.show()

# %%
## line plot
sns.lineplot(x='size',y='total_bill',data=tips)
plt.title("Line plot of total bill by size")
plt.show()

# %%
## bar plot
sns.barplot(x='day',y='total_bill',data=tips)
plt.title("Bar plot of total_bill by day")
plt.show()

# %%
## Box plot
sns.boxplot(x='day',y='total_bill',data=tips)
plt.title("Box plot of total_bill by day")
plt.show()

# %%
## Violine plot
sns.violinplot(x='day',y='total_bill',data=tips)
plt.show()

# %%
## Histogram plot 
sns.histplot(tips['total_bill'],bins=10,kde=False)
plt.show()

# %%
sns.histplot(tips['total_bill'],bins=10,kde=True)
plt.show()

# %%
## KDE plot

sns.kdeplot(tips['total_bill'],fill=True)
plt.show()

# %%
## Pair plot
sns.pairplot(tips)

# %%
## Heat map
corr=tips[['total_bill','tip','size']].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
import pandas as pd
sales_df=pd.read_csv("sales.csv")
sales_df.head(5)
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010        9925
# 1        Online              C  8/22/2012  963881480  9/15/2012        2804
# 2       Offline              L   5/2/2014  341417157   5/8/2014        1779
# 3        Online              C  6/20/2014  514321792   7/5/2014        8102
# 4       Offline              L   2/1/2013  115456712   2/6/2013        5062
#
#    Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# 0      255.28     159.42     2533654.00  1582243.50     951410.50
# 1      205.70     117.11      576782.80   328376.44     248406.36
# 2      651.21     524.96     1158502.59   933903.84     224598.75
# 3        9.33       6.92       75591.66    56065.84      19525.82
# 4      651.21     524.96     3296425.02  2657347.52     639077.50

# %%
## Plot total sales by product
plt.figure(figsize=(10,6))
sns.barplot(x='Item Type',y='Total Revenue',data=sales_df,estimator=sum)
plt.title("Total Revenue by product")
plt.xlabel("Item Type")
plt.ylabel("Total Revenue")
plt.show()
